# %%
# %run train_VLM_ablations.py --ablation swapped_blocks --config config.yaml --gpu 3 \
    --dino_model /home/ali/.cache/huggingface/hub/models--facebook--dinov2-large/snapshots/47b73eefe95e8d44ec3623f8890bd894b6ea2d6c/
# Out:
# /home/ali/.local/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# [DINOv2] Loading from /home/ali/.cache/huggingface/hub/models--facebook--dinov2-large/snapshots/47b73eefe95e8d44ec3623f8890bd894b6ea2d6c/
# [DINOv2] Ready: hidden=1024  layers=24  params=304.4M
#
# Running ablations: ['swapped_blocks']
# Checkpoint dir   : /mnt/share/ali/surgical_assessment_v2/checkpoints/ablations
#
#
# ...
#   ABLATION: swapped_blocks
#   Both encoders, block assignments fully swapped
# ...
# FlashAttention2 is not installed.
# ...

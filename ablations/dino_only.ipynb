# %%
# %run train_VLM_ablations.py --ablation dino_only --config config.yaml --gpu 1 \
    --dino_model /home/ali/.cache/huggingface/hub/models--facebook--dinov2-large/snapshots/47b73eefe95e8d44ec3623f8890bd894b6ea2d6c/
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# [DINOv2] Loading from /home/ali/.cache/huggingface/hub/models--facebook--dinov2-large/snapshots/47b73eefe95e8d44ec3623f8890bd894b6ea2d6c/
# [DINOv2] Ready: hidden=1024  layers=24  params=304.4M
#
# Running ablations: ['dino_only']
# Checkpoint dir   : /mnt/share/ali/surgical_assessment_v2/checkpoints/ablations
#
#
# ========================================================================
#   ABLATION: dino_only
#   DINOv2 intermediate features → LLM blocks [4,8,12]
# ========================================================================
# FlashAttention2 is not installed.
# Loaded InternVLChatModel  img_ctx_id=151671
# trainable params: 2,293,760 || all params: 753,926,144 || trainable%: 0.3042
# [DINOv2Injector] ViT layers [6, 12, 18] → LLM blocks [4, 8, 12]  init=near_zero
# [DINOv2Injector] Registering hooks at LLM blocks [4, 8, 12]
# [dino_only] Epoch 1:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 1:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 01 | 235.8min | loss=1.2789 | step_f1=0.575 | stage_f1=0.847
#   ↑ new best (score=0.575)
# [dino_only] Epoch 2:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 2:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 02 | 254.2min | loss=0.7023 | step_f1=0.604 | stage_f1=0.857
#   ↑ new best (score=0.604)
# [dino_only] Epoch 3:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 3:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 03 | 260.8min | loss=0.5860 | step_f1=0.662 | stage_f1=0.846
#   ↑ new best (score=0.662)
# [dino_only] Epoch 4:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 4:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 04 | 235.5min | loss=0.5116 | step_f1=0.720 | stage_f1=0.862
#   ↑ new best (score=0.720)
# [dino_only] Epoch 5:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 5:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 05 | 245.9min | loss=0.4592 | step_f1=0.590 | stage_f1=0.842
# [dino_only] Epoch 6:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 6:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 06 | 256.1min | loss=0.4190 | step_f1=0.686 | stage_f1=0.880
# [dino_only] Epoch 7:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 7:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 07 | 233.7min | loss=0.3710 | step_f1=0.722 | stage_f1=0.893
#   ↑ new best (score=0.722)
# [dino_only] Epoch 8:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 8:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 08 | 237.1min | loss=0.3317 | step_f1=0.696 | stage_f1=0.876
# [dino_only] Epoch 9:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 9:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 09 | 237.7min | loss=0.2929 | step_f1=0.741 | stage_f1=0.879
#   ↑ new best (score=0.741)
# [dino_only] Epoch 10:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 10:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 10 | 181.6min | loss=0.2595 | step_f1=0.710 | stage_f1=0.873
# [dino_only] Epoch 11:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 11:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 11 | 156.8min | loss=0.2245 | step_f1=0.718 | stage_f1=0.881
# [dino_only] Epoch 12:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 12:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 12 | 156.7min | loss=0.1824 | step_f1=0.714 | stage_f1=0.882
# [dino_only] Epoch 13:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 13:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 13 | 150.5min | loss=0.1608 | step_f1=0.737 | stage_f1=0.891
# [dino_only] Epoch 14:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 14:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 14 | 134.4min | loss=0.1262 | step_f1=0.732 | stage_f1=0.877
# [dino_only] Epoch 15:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 15:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 15 | 135.3min | loss=0.0922 | step_f1=0.740 | stage_f1=0.889
# [dino_only] Epoch 16:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 16:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 16 | 134.8min | loss=0.0800 | step_f1=0.752 | stage_f1=0.892
#   ↑ new best (score=0.752)
# [dino_only] Epoch 17:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 17:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 17 | 131.5min | loss=0.0542 | step_f1=0.751 | stage_f1=0.885
# [dino_only] Epoch 18:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 18:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 18 | 131.3min | loss=0.0508 | step_f1=0.743 | stage_f1=0.899
# [dino_only] Epoch 19:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 19:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 19 | 130.7min | loss=0.0370 | step_f1=0.743 | stage_f1=0.898
# [dino_only] Epoch 20:   0%|          | 0/8284 [00:00<?, ?it/s]
# [dino_only] Val 20:   0%|          | 0/1234 [00:00<?, ?it/s]
# [dino_only] Epoch 20 | 144.5min | loss=0.0256 | step_f1=0.749 | stage_f1=0.902
#
# [dino_only] Best epoch: 16  score: 0.7519
# [dino_only] Test:   0%|          | 0/2334 [00:00<?, ?it/s]
# [dino_only] TEST step : {'acc': 0.7697368421052632, 'macro_f1': 0.7551853137192465, 'weighted_f1': 0.7583940597311284, 'kappa': 0.7514942241821636, 'n': 1216}
# [dino_only] TEST stage: {'acc': 0.9141323792486583, 'macro_f1': 0.9012365521353223, 'weighted_f1': 0.913468674970072, 'kappa': 0.8650902390032607, 'n': 1118}
#
# ────────────────────────────────────────────────────────────────────────
#   DINO_ONLY STEP
# ────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#     step_001       0.82      0.84      0.83        88
#     step_002       0.70      0.80      0.75        92
#     step_003       0.86      0.75      0.80        96
#     step_004       0.80      0.90      0.84       108
#     step_005       0.80      0.82      0.81       107
#     step_006       0.73      0.65      0.69        89
#     step_007       0.58      0.76      0.66        83
#     step_008       0.62      0.41      0.50        85
#     step_009       0.66      0.65      0.65        68
#     step_010       0.88      0.86      0.87        71
#     step_011       0.66      0.72      0.69        81
#     step_012       0.90      0.74      0.81        61
#     step_013       0.88      0.94      0.91        89
#
#    micro avg       0.76      0.76      0.76      1118
#    macro avg       0.76      0.76      0.76      1118
# weighted avg       0.76      0.76      0.76      1118
#
#
# ────────────────────────────────────────────────────────────────────────
#   DINO_ONLY STAGE
# ────────────────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#     stage_01       0.94      0.98      0.96       384
#     stage_02       0.93      0.91      0.92       503
#     stage_03       0.84      0.81      0.83       231
#
#     accuracy                           0.91      1118
#    macro avg       0.90      0.90      0.90      1118
# weighted avg       0.91      0.91      0.91      1118
#
#
# [Summary] Saved 1 results → /mnt/share/ali/surgical_assessment_v2/checkpoints/ablations/ablation_summary.json
#
# ==========================================================================================
#   ABLATION SUMMARY TABLE
# ==========================================================================================
#   Ablation                      Step Acc   Step F1   Step κ   Stg Acc    Stg F1    Stg κ  BestEp
#   ----------------------------------------------------------------------------------------
#   dino_only                    0.7697    0.7552    0.7515   0.9141    0.9012    0.8651      16
# ==========================================================================================
#
# All done. Full results in: /mnt/share/ali/surgical_assessment_v2/checkpoints/ablations
